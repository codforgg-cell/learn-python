# %%
score = int(input("점수를 입력해주세요"))
if 91<= score <= 100:
  print("A")
if 81<= score <= 90:
  print("B")
if 71<= score <= 80:
  print("c")
if 61<= score <= 70:
  print("d")
if score<=60:
   print("f")
# Out:
# 점수를 입력해주세요5
# f

# %%
tall = int(input("키는?"))
weight = int(input("몸무게는?"))
s = (tall-100)*0.9
print("="*50)
if weight >= s:
  print("과체중입니다")
else:
    print("정상체중 또는 저체중입니다")
# Out:
# 키는?5
# 몸무게는?5
# ...
# 과체중입니다

# %%
seats =[[False,True,False],[False,True,False],[False,True,False]]
line = int(input("Type line number"))
seat = int(input("Type seat number"))
