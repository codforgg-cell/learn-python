# %%
print("Hi")
# Out:
# Hi

# %%
score = int(input("점수를 입력해주세요"))
if 91<= score <= 100:
  print("A")
if 81<= score <= 90:
  print("B")
if 71<= score <= 80:
  print("c")
if 61<= score <= 70:
  print("d")
if score<=60:
   print("f")
# Out:
# f

# %%
score = int(input("점수를 입력해주세요"))
if 91<= score <= 100:
  print("A")
if 81<= score <= 90:
  print("B")
if 71<= score <= 80:
  print("c")
if 61<= score <= 70:
  print("d")
if score<=60:
   print("f")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 score = int(input("점수를 입력해주세요"))
#       2 if 91<= score <= 100:
#       3   print("A")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
tall = int(input("키는?"))
weight = int(input("몸무게는?"))
s = (tall-100)*0.9
print("="*50)
if weight >= s:
  print("과체중입니다")
else:
    print("정상체중 또는 저체중입니다")
